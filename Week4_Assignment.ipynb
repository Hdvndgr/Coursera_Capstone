# %% [markdown]
# <h1>1. Preparation of Datasets</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import folium
from geopy.geocoders import Nominatim
import requests

# %% [markdown]
# We will prepare two data sets;
# 1. City of Amsterdam / Netherlands
# 2. City of Istanbul / Turkey

# %%
amsterdam_data = pd.read_csv("datasets/GEBIED_BUURTEN.csv", sep=';')
amsterdam_data.head()
# Out:
#    OBJECTNUMMER Buurt_code                          Buurt  \
# 0             1       F81d            Calandlaan/Lelylaan
# 1             2       F81e                Osdorp Zuidoost
# 2             3       F82a            Osdorp Midden Noord
# 3             4       F82b             Osdorp Midden Zuid
# 4             5       F82c  Zuidwestkwadrant Osdorp Noord
#
#   Buurtcombinatie_code Stadsdeel_code    Opp_m2  \
# 0                  F81              F  275360.0
# 1                  F81              F  519366.0
# 2                  F82              F  215541.0
# 3                  F82              F  258379.0
# 4                  F82              F  240774.0
#
#                                          WKT_LNG_LAT  \
# 0  POLYGON((4.800801 52.355175,4.809055 52.356842...
# 1  POLYGON((4.818583 52.357519,4.818622 52.356295...
# 2  POLYGON((4.786657 52.362712,4.795326 52.364434...
# 3  POLYGON((4.788293 52.359736,4.796917 52.36148,...
# ...

# %%
len(amsterdam_data['Stadsdeel_code'].unique())
# Out:
# 8

# %%
amsterdam_data.groupby('Stadsdeel_code').count().sum()
# Out:
# OBJECTNUMMER            481
# Buurt_code              481
# Buurt                   481
# Buurtcombinatie_code    481
# Opp_m2                  481
# WKT_LNG_LAT             481
# WKT_LAT_LNG             481
# LNG                     481
# LAT                     481
# Unnamed: 10               0
# dtype: int64

# %%
amsterdam_data.loc[amsterdam_data.Stadsdeel_code == 'B']
# Out:
#      OBJECTNUMMER Buurt_code                     Buurt Buurtcombinatie_code  \
# 300           301       B10h            Westhaven Zuid                  B10
# 359           360       B10a  Coenhaven/Mercuriushaven                  B10
# 360           361       B10b             Alfa-driehoek                  B10
# 361           362       B10c            Petroleumhaven                  B10
# 362           363       B10d           Westhaven Noord                  B10
# 363           364       B10e           Vervoerscentrum                  B10
# 364           365       B10f              Amerikahaven                  B10
# 365           366       B10g               Afrikahaven                  B10
#
#     Stadsdeel_code      Opp_m2  \
# 300              B    469952.0
# 359              B   3022480.0
# 360              B    406268.0
# 361              B   3217160.0
# 362              B   5696140.0
# 363              B    700278.0
# 364              B  10121500.0
# ...

# %%
amsterdam_data.groupby('Stadsdeel_code').Buurt.count()
# Out:
# Stadsdeel_code
# A    70
# B     8
# E    67
# F    68
# K    76
# M    78
# N    66
# T    48
# Name: Buurt, dtype: int64

# %%
len(amsterdam_data.Buurt_code.unique())
# Out:
# 481

# %%
amsterdam_data.loc[amsterdam_data.Stadsdeel_code == 'E']
# Out:
#      OBJECTNUMMER Buurt_code                            Buurt  \
# 82             83       E12b                  Houthavens Oost
# 83             84       E13a                   Zeeheldenbuurt
# 84             85       E13b      Spaarndammerbuurt Noordoost
# 85             86       E13c       Spaarndammerbuurt Zuidoost
# 86             87       E13d       Spaarndammerbuurt Zuidwest
# 87             88       E13e         Spaarndammerbuurt Midden
# 88             89       E13g                 Westergasfabriek
# 89             90       E14a             De Wittenbuurt Noord
# 90             91       E14b              De Wittenbuurt Zuid
# 91             92       E14c      Staatsliedenbuurt Noordoost
# 92             93       E14d            Fannius Scholtenbuurt
# 93             94       E14e                  Westerstaatsman
# 94             95       E14f                    Buyskade e.o.
# 95             96       E15a                          Ecowijk
# ...

# %%
stadsdeelen = {'B':'Westpoort', 'T':'Zuidoost', 'M':'Oost', 'A':'Centrum',  
               'N':'Noord', 'F':'Nieuw-West', 'E':'West', 'K':'Zuid'}
cols = ['Buurt_code', 'Buurt', 'Stadsdeel_code', 'LNG', 'LAT']
ams_df = amsterdam_data.loc[:, cols]
ams_df.head()
# Out:
#   Buurt_code                          Buurt Stadsdeel_code       LNG  \
# 0       F81d            Calandlaan/Lelylaan              F  4.809697
# 1       F81e                Osdorp Zuidoost              F  4.811344
# 2       F82a            Osdorp Midden Noord              F  4.791792
# 3       F82b             Osdorp Midden Zuid              F  4.793781
# 4       F82c  Zuidwestkwadrant Osdorp Noord              F  4.795597
#
#          LAT
# 0  52.355708
# 1  52.353736
# 2  52.362078
# 3  52.358838
# 4  52.355523

# %%
ams_df['Stadsdeel'] = ams_df.replace({'Stadsdeel_code': stadsdeelen})['Stadsdeel_code']

# %%
ams_df.head()
# Out:
#   Buurt_code                          Buurt Stadsdeel_code       LNG  \
# 0       F81d            Calandlaan/Lelylaan              F  4.809697
# 1       F81e                Osdorp Zuidoost              F  4.811344
# 2       F82a            Osdorp Midden Noord              F  4.791792
# 3       F82b             Osdorp Midden Zuid              F  4.793781
# 4       F82c  Zuidwestkwadrant Osdorp Noord              F  4.795597
#
#          LAT   Stadsdeel
# 0  52.355708  Nieuw-West
# 1  52.353736  Nieuw-West
# 2  52.362078  Nieuw-West
# 3  52.358838  Nieuw-West
# 4  52.355523  Nieuw-West
